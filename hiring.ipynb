# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/My Drive/kaggle'
# %cd /content/drive/My Drive/kaggle
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/kaggle

# %%
# !kaggle datasets download -d pankeshpatel/hiring
# Out:
# ...
#   0% 0.00/289 [00:00<?, ?B/s]
# 100% 289/289 [00:00<00:00, 57.6kB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  archive (7).zip
#   inflating: hiring.csv
#
# Archive:  hiring.zip
# replace hiring.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: hiring.csv
#
# 2 archives were successfully processed.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import statistics as st
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model

# %%
df = pd.read_csv("/content/drive/My Drive/kaggle/hiring.csv")
df.head()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000

# %%
median = df.median()
median
# Out:
# test_score(out of 10)             8.0
# interview_score(out of 10)        7.5
# salary($)                     63500.0
# dtype: float64

# %%
df1 = df.experience.fillna(0)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df2 = df.drop('experience',axis = 'columns')
df2
# Out:
#    test_score(out of 10)  interview_score(out of 10)  salary($)
# 0                    8.0                           9      50000
# 1                    8.0                           6      45000
# 2                    6.0                           7      60000
# 3                   10.0                          10      65000
# 4                    9.0                           6      70000
# 5                    7.0                          10      62000
# 6                    NaN                           7      72000
# 7                    7.0                           8      80000

# %%
model = linear_model.LinearRegression()

# %%
experience = [0,0,5,2,7,3,10,11]
df['experience'] = experience
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000
#
#    test_score
# 0         8.0
# 1         8.0
# 2         6.0
# 3        10.0
# 4         9.0
# 5         7.0
# 6         8.0
# 7         7.0

# %%
median = df.median()
median
# Out:
# experience                        4.0
# test_score(out of 10)             8.0
# interview_score(out of 10)        7.5
# salary($)                     63500.0
# test_score                        8.0
# dtype: float64

# %%
df.experience = df.experience.fillna(df.experience.median())
df.experience
# Out:
# 0     0
# 1     0
# 2     5
# 3     2
# 4     7
# 5     3
# 6    10
# 7    11
# Name: experience, dtype: int64

# %%
median = df.median()

# %%
p = df.drop('salary($)',axis = 'columns')
p
a = df['salary($)']
p
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  test_score
# 0           0                    8.0                           9         8.0
# 1           0                    8.0                           6         8.0
# 2           5                    6.0                           7         6.0
# 3           2                   10.0                          10        10.0
# 4           7                    9.0                           6         9.0
# 5           3                    7.0                          10         7.0
# 6          10                    NaN                           7         8.0
# 7          11                    7.0                           8         7.0

# %%
df_new = df['test_score(out of 10)']

# %%
test_score = df['test_score(out of 10)']
df['test_score'] = test_score
df.drop('test_score(out of 10)', axis = 'columns')
# Out:
#    experience  interview_score(out of 10)  salary($)  test_score
# 0           0                           9      50000         8.0
# 1           0                           6      45000         8.0
# 2           5                           7      60000         6.0
# 3           2                          10      65000        10.0
# 4           7                           6      70000         9.0
# 5           3                          10      62000         7.0
# 6          10                           7      72000         NaN
# 7          11                           8      80000         7.0

# %%
df.test_score = df.test_score.fillna(df.test_score.median())
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000
#
#    test_score
# 0         8.0
# 1         8.0
# 2         6.0
# 3        10.0
# 4         9.0
# 5         7.0
# 6         8.0
# 7         7.0

# %%
new = df.drop('test_score(out of 10)', axis = 'columns')
new
# Out:
#    experience  interview_score(out of 10)  salary($)  test_score
# 0           0                           9      50000         8.0
# 1           0                           6      45000         8.0
# 2           5                           7      60000         6.0
# 3           2                          10      65000        10.0
# 4           7                           6      70000         9.0
# 5           3                          10      62000         7.0
# 6          10                           7      72000         8.0
# 7          11                           8      80000         7.0

# %%
model = linear_model.LinearRegression()
po = df['salary($)']
model.fit(new.drop('salary($)',axis = 'columns'),po)
new
# Out:
#    experience  interview_score(out of 10)  salary($)  test_score
# 0           0                           9      50000         8.0
# 1           0                           6      45000         8.0
# 2           5                           7      60000         6.0
# 3           2                          10      65000        10.0
# 4           7                           6      70000         9.0
# 5           3                          10      62000         7.0
# 6          10                           7      72000         8.0
# 7          11                           8      80000         7.0

# %%
model.predict([[2,6,9]])
# Out:
# array([53205.96797671])

# %%
model.predict([[12,10,10]])
# Out:
# array([92002.18340611])
